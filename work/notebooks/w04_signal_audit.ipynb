# %% [markdown]
# # ML-06 — Signal Audit: Do the Flags Hold?
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tahir-MD/FlyRank-Week-01/blob/main/work/notebooks/w04_signal_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Distributions
#
# *Look before deciding: distributions of your key fields. Note the heavy tails.*

# %%
# This cell is for CODE (numbers, a query, a check).
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv")
print(df.shape)

key_cols = ["impressions_90d", "clicks_90d", "sessions_90d", "ctr",
            "avg_position", "engagement_rate", "trend_pct", "search_volume"]

print(df[key_cols].describe())

# heavy-tail check: compare median to the 99th percentile
for col in key_cols:
    print(col, "median:", df[col].median(), " p99:", df[col].quantile(0.99), " max:", df[col].max())
# Out:
# (30000, 44)
#        impressions_90d    clicks_90d  sessions_90d           ctr  \
# count     30000.000000  30000.000000  30000.000000  30000.000000
# mean       5200.366300     16.097333     37.066633      0.510733
# std       16838.019547     75.076958    107.069131      3.279162
# min           1.000000      0.000000      1.000000      0.000000
# 25%          81.000000      0.000000      2.000000      0.000000
# 50%         731.000000      1.000000      7.000000      0.070000
# 75%        3615.250000      7.000000     27.000000      0.290000
# max      517715.000000   4178.000000   4345.000000    100.000000
#
#        avg_position  engagement_rate     trend_pct  search_volume
# count   30000.00000     30000.000000  26612.000000   27532.000000
# mean       16.34238         2.534520     -4.785969     158.882391
# std        15.21679         8.310096    473.861780    1518.270825
# min         0.00000         0.000000   -100.000000       0.000000
# ...

# %% [markdown]
# ## 2. Signal test #1 / #2 / #3 (verdict each)
#
# *Three safe signals, each with a mini-test and a verdict: CONFIRMED / OPPOSITE / MIXED / FALSE.*

# %%
# This cell is for CODE (numbers, a query, a check).
declining = df[df["trend_direction"] == "down"]
stable = df[df["trend_direction"] != "down"]

def compare(col):
    print(f"{col}: declining median = {declining[col].median():.3f} | "
          f"stable median = {stable[col].median():.3f}")

compare("engagement_rate")

compare("ctr")

compare("days_since_last_update")
# Out:
# engagement_rate: declining median = 0.000 | stable median = 0.000
# ctr: declining median = 0.080 | stable median = 0.040
# days_since_last_update: declining median = 20.000 | stable median = 20.000

# %% [markdown]
# ## 3. The flag-linked test
#
# *Pick a signal one of FlyRank's real flags relies on. Does the data support the rule's assumption?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Example: FlyRank's real flag assumes "low position + low CTR = needs a refresh"
# Test whether that assumption actually holds in this data
by_position_tier = df.groupby("position_tier")["ctr"].median().sort_index()
print(by_position_tier)

# does CTR actually drop as position tier gets worse?
# Out:
# position_tier
# deep        0.00
# page_1      0.16
# page_3_5    0.03
# striking    0.11
# top_3       0.00
# Name: ctr, dtype: float64

# %% [markdown]
# ## 4. What this means in practice
#
# *Two or three sentences: what a content team should take from this.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
flagged_share = (df["trend_direction"] == "down").mean()
print(f"{flagged_share:.1%} of pages are currently declining")
# Out:
# 54.2% of pages are currently declining

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
